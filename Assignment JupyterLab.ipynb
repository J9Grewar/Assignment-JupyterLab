# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Janine Grewar**
#
# Regulatory Data Scientist

# %% [markdown]
# _I am interested in data science because I am curious about how we can improve controls to prevent money laundering with the use of data.  Using data can support us to be more pro-active by identifying trends and to put preventative measures in place._

# %% [markdown]
# ### I am going to be boring and just give you my age

# %%
7+33
# Out:
# 40

# %% [markdown]
# [hyperlink](https://www.google.com) | My age | Be Bold
# --- | --- | ---
# *Google* | `7 + 33` | **but be nice**
# I | was | here
